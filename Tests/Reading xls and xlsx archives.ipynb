# %%
import pandas as pd

# %%
# dados = pd.ExcelFile('/home/arthur/Documentos/UFC/Oficina de R/Empresa.xlsx')
# dados = pd.read_excel(dados)
dados = pd.read_excel('../UFC/Oficina de R/Empresa.xlsx')
dados.index.name = 'empresas'
dados.name = 'dados dos funcionarios'
dados
# Out:
#           funcionario  civil  instrucao  filhos  salario  anos  meses  regiao
# empresas
# 0                   1      1          1     NaN     4.00    26      3       1
# 1                   2      2          1     1.0     4.56    32     10       2
# 2                   3      2          1     2.0     5.25    36      5       2
# 3                   4      1          2     NaN     5.73    20     10       3
# 4                   5      1          1     NaN     6.26    40      7       3
# 5                   6      2          1     0.0     6.66    28      0       1
# 6                   7      1          1     NaN     6.86    41      0       1
# 7                   8      1          1     NaN     7.39    43      4       2
# 8                   9      2          2     1.0     7.59    34     10       2
# 9                  10      1          2     NaN     7.44    23      6       3
# 10                 11      2          2     2.0     8.12    33      6       1
# ...

# %%
dados.describe().round(3)
# Out:
#        funcionario   civil  instrucao  filhos  salario    anos   meses  regiao
# count       36.000  36.000     36.000  20.000   36.000  36.000  36.000  36.000
# mean        18.500   1.556      1.833   1.650   11.122  34.583   5.611   2.028
# std         10.536   0.504      0.697   1.268    4.587   6.737   3.289   0.845
# min          1.000   1.000      1.000   0.000    4.000  20.000   0.000   1.000
# 25%          9.750   1.000      1.000   1.000    7.552  30.000   3.750   1.000
# 50%         18.500   2.000      2.000   2.000   10.165  34.500   6.000   2.000
# 75%         27.250   2.000      2.000   2.000   14.060  40.000   8.000   3.000
# max         36.000   2.000      3.000   5.000   23.300  48.000  11.000   3.000

# %%
max_func = dados['funcionario'].max()
max_func
# Out:
# 36

# %%
dados['filhos'].isna().sum()
# Out:
# 16

# %%
dados.fillna(0)
# Out:
#           funcionario  civil  instrucao  filhos  salario  anos  meses  regiao
# empresas
# 0                   1      1          1     0.0     4.00    26      3       1
# 1                   2      2          1     1.0     4.56    32     10       2
# 2                   3      2          1     2.0     5.25    36      5       2
# 3                   4      1          2     0.0     5.73    20     10       3
# 4                   5      1          1     0.0     6.26    40      7       3
# 5                   6      2          1     0.0     6.66    28      0       1
# 6                   7      1          1     0.0     6.86    41      0       1
# 7                   8      1          1     0.0     7.39    43      4       2
# 8                   9      2          2     1.0     7.59    34     10       2
# 9                  10      1          2     0.0     7.44    23      6       3
# 10                 11      2          2     2.0     8.12    33      6       1
# ...
